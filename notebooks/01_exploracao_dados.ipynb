# %% [markdown]
# # 📊 Exploração de Dados - Acidentes PRF
#
# Este notebook apresenta a análise exploratória dos dados de acidentes da Polícia Rodoviária Federal.
#
# ## Objetivos
# 1. Entender a estrutura dos dados
# 2. Identificar padrões e tendências
# 3. Analisar correlações
# 4. Preparar insights para modelagem

# %%
# Imports necessários
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Configurações
plt.style.use('default')
pd.set_option('display.max_columns', None)

print("✅ Bibliotecas importadas com sucesso!")
